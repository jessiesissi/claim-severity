# %% [markdown]
# # Data Pre-processing

# %%
import numpy as np
import pandas as pd     
import re    
import time

# %%
class Preprocessing:

    
    def ADDDVREBCTEXT1(self, data, MyData, feature_names):
        
        ADDDVREBCTEXT1_content = list(np.load('ADDDVREBCTEXT1_content.npy'))
        for i in range(680):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDDVREBCTEXT1.isnull()[i] == True:
                continue
            
            c = data.ADDDVREBCTEXT1.loc[i].replace(' ', '').lower()
            
            if c in ADDDVREBCTEXT1_content:
                MyData['ADDDVREBCTEXT1' + '_' + c].loc[i] = 1
                
        
    def ADDDVREBCTEXT2(self, data, MyData, feature_names):
        
        ADDDVREBCTEXT2_content = list(np.load('ADDDVREBCTEXT2_content.npy'))
        for i in range(680,1159):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDDVREBCTEXT2.isnull()[i] == True:
                continue
            
            c = data.ADDDVREBCTEXT2.loc[i].replace(' ', '').lower()
            
            if c in ADDDVREBCTEXT2_content:
                MyData['ADDDVREBCTEXT2' + '_' + c].loc[i] = 1
                
                
    
    def ADDDVRLICTYPE1(self, data, MyData, feature_names):
        
        ADDDVRLICTYPE1_content = ['e', 'f', 'i', 'n', 'r', 's', 'x']
        
        for i in range(1159, 1166):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDDVRLICTYPE1.isnull()[i] == True:
                continue
            
            c = data.ADDDVRLICTYPE1.loc[i].replace(' ', '').lower()
            
            if c in ADDDVRLICTYPE1_content:
                MyData['ADDDVRLICTYPE1' + '_' + c].loc[i] = 1
    
    
    
    def ADDDVRLICTYPE2(self, data, MyData, feature_names):
        
        ADDDVRLICTYPE2_content = ['e', 'f',  'n',  's']
        
        for i in range(1166,1170):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDDVRLICTYPE2.isnull()[i] == True:
                continue
            
            c = data.ADDDVRLICTYPE2.loc[i].replace(' ', '').lower()
            
            if c in ADDDVRLICTYPE2_content:
                MyData['ADDDVRLICTYPE2' + '_' + c].loc[i] = 1
    
    
    def ADDDVRMARITALSTATUS1(self, data, MyData, feature_names):
        
        ADDDVRMARITALSTATUS1_content = ['divorced', 'married',  'marriedcommonlaw',  'notapplicable', 'partnered', 'partneredcivil', 'separated', 'single', 'widowed' ]
        
        for i in range(1170, 1179):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDDVRMARITALSTATUS1.isnull()[i] == True:
                continue
            
            
            c = re.sub('[^a-zA-Z0-9]','',data.ADDDVRMARITALSTATUS1.loc[i]).lower()
            if c in ADDDVRMARITALSTATUS1_content:
                MyData['ADDDVRMARITALSTATUS1' + '_' + c].loc[i] = 1
    
    
    
    def ADDDVRMARITALSTATUS2(self, data, MyData, feature_names):
        
        ADDDVRMARITALSTATUS2_content = ['divorced', 'married',  'marriedcommonlaw',  'notapplicable', 'partnered', 'partneredcivil', 'separated', 'single', 'widowed' ]
        
        for i in range(1179, 1188):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDDVRMARITALSTATUS2.isnull()[i] == True:
                continue
            
            c = re.sub('[^a-zA-Z0-9]','',data.ADDDVRMARITALSTATUS2.loc[i]).lower()
            
            if c in ADDDVRMARITALSTATUS2_content:
                MyData['ADDDVRMARITALSTATUS2' + '_' + c].loc[i] = 1
    
   
    
    
    def ADDDVROCCUPATION1(self, data, MyData, feature_names):
        
        ADDDVROCCUPATION1_content = list(np.load('ADDDVROCCUPATION1_content.npy'))
        for i in range(1188,2230):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDDVROCCUPATION1.isnull()[i] == True:
                continue
            
            c = data.ADDDVROCCUPATION1.loc[i].replace(' ', '').lower()
            
            if c in ADDDVROCCUPATION1_content:
                MyData['ADDDVROCCUPATION1' + '_' + c].loc[i] = 1
                
    
    
    
    def ADDDVROCCUPATION2(self, data, MyData, feature_names):
        
        ADDDVROCCUPATION2_content = list(np.load('ADDDVROCCUPATION2_content.npy'))
        for i in range(2230,2832):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDDVROCCUPATION2.isnull()[i] == True:
                continue
            
            c = data.ADDDVROCCUPATION2.loc[i].replace(' ', '').lower()
            
            if c in ADDDVROCCUPATION2_content:
                MyData['ADDDVROCCUPATION2' + '_' + c].loc[i] = 1
                
    
    
    def ADDDVROCCUPATIONTEXT1(self, data, MyData, feature_names):
        
        ADDDVROCCUPATIONTEXT1_content = list(np.load('ADDDVROCCUPATIONTEXT1_content.npy'))
        for i in range(2832,3873):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDDVROCCUPATIONTEXT1.isnull()[i] == True:
                continue
            
            c = re.sub('[^a-zA-Z0-9]','',data.ADDDVROCCUPATIONTEXT1.loc[i]).lower()
            
            if c in ADDDVROCCUPATIONTEXT1_content:
                MyData['ADDDVROCCUPATIONTEXT1' + '_' + c].loc[i] = 1
    
    
    
    def ADDDVROCCUPATIONTEXT2(self, data, MyData, feature_names):
        
        ADDDVROCCUPATIONTEXT2_content = list(np.load('ADDDVROCCUPATIONTEXT2_content.npy'))
        for i in range(3873,4474):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDDVROCCUPATIONTEXT2.isnull()[i] == True:
                continue
            
            c = re.sub('[^a-zA-Z0-9]','',data.ADDDVROCCUPATIONTEXT2.loc[i]).lower()
            
            if c in ADDDVROCCUPATIONTEXT2_content:
                MyData['ADDDVROCCUPATIONTEXT2' + '_' + c].loc[i] = 1
    
    
    
    def ADDDVRSEX2(self, data, MyData, feature_names):
        
        ADDDVRSEX2_content = ['male', 'female']
        
        for i in range(4474,4476):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDDVRSEX2.isnull()[i] == True:
                continue
            
            c = data.ADDDVRSEX2.loc[i].replace(' ', '').lower()
            
            if c in ADDDVRSEX2_content:
                MyData['ADDDVRSEX2' + '_' + c].loc[i] = 1
    
    
    
    def ADDITIONALDRIVER1(self, data, MyData, feature_names):
        
        ADDITIONALDRIVER1_content = ['doctor', 'miss', 'mr', 'mrs', 'ms', 'rabbi']
        
        for i in range(4476,4482):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDITIONALDRIVER1.isnull()[i] == True:
                continue
            
            c = data.ADDITIONALDRIVER1.loc[i].split(' ')[0].lower()
            
            if c in ADDITIONALDRIVER1_content:
                MyData['ADDITIONALDRIVER1' + '_' + c].loc[i] = 1
    
    
    
    
    def ADDITIONALDRIVER1REL(self, data, MyData, feature_names):
        
        ADDITIONALDRIVER1REL_content = ['brotherorsister', 'businesspartner', 'commonlawpartner', 'daughterinlaworsoninlaw', 'daughterorson', 'director', 'employeeofproposer', 'employerofproposer', 'family', 'lodger', 'notapplicable', 'notrelated', 'parent', 'partnercivil', 'proposer', 'sisterinlaworbrotherinlaw', 'spouse', 'unrelated']
        
        for i in range(4482,4500):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDITIONALDRIVER1REL.isnull()[i] == True:
                continue
            
            c = re.sub('[^a-zA-Z]','',data.ADDITIONALDRIVER1REL.loc[i]).lower()
            
            if c in ADDITIONALDRIVER1REL_content:
                MyData['ADDITIONALDRIVER1REL' + '_' + c].loc[i] = 1
 
    
    
    def ADDITIONALDRIVER2(self, data, MyData, feature_names):
        
        ADDITIONALDRIVER2_content = ['doctor', 'madam', 'miss', 'mr', 'mrs', 'ms']
        
        for i in range(4500,4506):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDITIONALDRIVER2.isnull()[i] == True:
                continue
            
            c = data.ADDITIONALDRIVER2.loc[i].split(' ')[0].lower()
            
            if c in ADDITIONALDRIVER2_content:
                MyData['ADDITIONALDRIVER2' + '_' + c].loc[i] = 1
    
    

    
    def ADDITIONALDRIVER2REL(self, data, MyData, feature_names):
        
        ADDITIONALDRIVER2REL_content = ['brotherorsister', 'businesspartner', 'commonlawpartner', 'daughterinlaworsoninlaw', 'daughterorson', 'director', 'employeeofproposer', 'employerofproposer', 'family',  'notapplicable', 'notrelated', 'parent', 'partnercivil', 'proposer', 'sisterinlaworbrotherinlaw', 'spouse', 'unrelated']
        
        for i in range(4506,4523):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.ADDITIONALDRIVER2REL.isnull()[i] == True:
                continue
            
            c = re.sub('[^a-zA-Z]','',data.ADDITIONALDRIVER2REL.loc[i]).lower()
            
            if c in ADDITIONALDRIVER2REL_content:
                MyData['ADDITIONALDRIVER2REL' + '_' + c].loc[i] = 1
 
    
    
    
    def CONV1OFFENCECODE(self, data, MyData, feature_names):
        
        CONV1OFFENCECODE_content = list(np.load('CONV1OFFENCECODE_content.npy'))
        for i in range(4523,4601):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.CONV1OFFENCECODE.isnull()[i] == True:
                continue
            
            c = data.CONV1OFFENCECODE.loc[i].replace(' ', '').lower()
            
            if c in CONV1OFFENCECODE_content:
                MyData['CONV1OFFENCECODE' + '_' + c].loc[i] = 1
    
    
    
    def CONV2OFFENCECODE(self, data, MyData, feature_names):
        
        CONV2OFFENCECODE_content = list(np.load('CONV2OFFENCECODE_content.npy'))
        for i in range(4601,4652):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.CONV2OFFENCECODE.isnull()[i] == True:
                continue
            
            c = data.CONV2OFFENCECODE.loc[i].replace(' ', '').lower()
            
            if c in CONV2OFFENCECODE_content:
                MyData['CONV2OFFENCECODE' + '_' + c].loc[i] = 1
    
    
    
    def COVER(self, data, MyData, feature_names):
        
        COVER_content = ['comp', 'tpft', 'tpo']
        
        for i in range(4652,4655):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.COVER.isnull()[i] == True:
                continue
            
            c = data.COVER.loc[i].replace(' ', '').lower()
            
            if c in COVER_content:
                MyData['COVER' + '_' + c].loc[i] = 1
    
   
  
    def DRIVERNAMEACCT1(self, data, MyData, feature_names):
        
        DRIVERNAMEACCT1_content = ['doctor', 'insured', 'miss', 'mr', 'mrs', 'ms']
        
        for i in range(4655,4661):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.DRIVERNAMEACCT1.isnull()[i] == True:
                continue
            
            c = data.DRIVERNAMEACCT1.loc[i].split(' ')[0].lower()
            
            if c in DRIVERNAMEACCT1_content:
                MyData['DRIVERNAMEACCT1' + '_' + c].loc[i] = 1
    
    
    def DRIVERNAMEACCT2(self, data, MyData, feature_names):
        
        DRIVERNAMEACCT2_content = ['doctor', 'insured', 'miss', 'mr', 'mrs', 'ms']
        
        for i in range(4661,4667):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.DRIVERNAMEACCT2.isnull()[i] == True:
                continue
            
            c = data.DRIVERNAMEACCT2.loc[i].split(' ')[0].lower()
            
            if c in DRIVERNAMEACCT2_content:
                MyData['DRIVERNAMEACCT2' + '_' + c].loc[i] = 1
    
    
 
 
    def DRIVERNAMECONV1(self, data, MyData, feature_names):
        
        DRIVERNAMECONV1_content = ['doctor', 'insured', 'miss', 'mr', 'mrs', 'ms']
        
        for i in range(4667,4673):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.DRIVERNAMECONV1.isnull()[i] == True:
                continue
            
            c = data.DRIVERNAMECONV1.loc[i].split(' ')[0].lower()
            
            if c in DRIVERNAMECONV1_content:
                MyData['DRIVERNAMECONV1' + '_' + c].loc[i] = 1
    
    
    
    def DRIVERNAMECONV2(self, data, MyData, feature_names):
        
        DRIVERNAMECONV2_content = ['doctor', 'insured', 'miss', 'mr', 'mrs', 'ms']
        
        for i in range(4673,4679):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.DRIVERNAMECONV2.isnull()[i] == True:
                continue
            
            c = data.DRIVERNAMECONV2.loc[i].split(' ')[0].lower()
            
            if c in DRIVERNAMECONV2_content:
                MyData['DRIVERNAMECONV2' + '_' + c].loc[i] = 1
    
    
    
    def EMPLOYMENTSTATUS(self, data, MyData, feature_names):
        
        EMPLOYMENTSTATUS_content = list(np.load('EMPLOYMENTSTATUS_content.npy'))
        
        for i in range(4679,4692):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.EMPLOYMENTSTATUS.isnull()[i] == True:
                continue
            
            c = re.sub('[^a-zA-Z]','',data.EMPLOYMENTSTATUS.loc[i]).lower()
            
            if c in EMPLOYMENTSTATUS_content:
                MyData['EMPLOYMENTSTATUS' + '_' + c].loc[i] = 1
    
    
    def FAULTCODE1(self, data, MyData, feature_names):
        
        FAULTCODE1_content = list(np.load('FAULTCODE1_content.npy'))
        
        for i in range(4692,4723):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.FAULTCODE1.isnull()[i] == True:
                continue
            
            c = re.sub('[^a-zA-Z]','',data.FAULTCODE1.loc[i]).lower()
            
            if c in FAULTCODE1_content:
                MyData['FAULTCODE1' + '_' + c].loc[i] = 1
    
    
    
    def FAULTCODE2(self, data, MyData, feature_names):
        
        FAULTCODE2_content = list(np.load('FAULTCODE2_content.npy'))
        
        for i in range(4723,4745):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.FAULTCODE2.isnull()[i] == True:
                continue
            
            c = re.sub('[^a-zA-Z]','',data.FAULTCODE2.loc[i]).lower()
            
            if c in FAULTCODE2_content:
                MyData['FAULTCODE2' + '_' + c].loc[i] = 1
    
    
    
    
    def FUEL(self, data, MyData, feature_names):
        
        FUEL_content = ['diesel', 'electric', 'petrol']
        
        for i in range(4745,4748):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.FUEL.isnull()[i] == True:
                continue
            
            c = data.FUEL.loc[i].split(' ')[0].lower()
            
            if c in FUEL_content:
                MyData['FUEL' + '_' + c].loc[i] = 1
    
    
    
    def GARAGEDDETAILS(self, data, MyData, feature_names):
        
        GARAGEDDETAILS_content = list(np.load('GARAGEDDETAILS_content.npy'))
        
        for i in range(4748, 4763):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.GARAGEDDETAILS.isnull()[i] == True:
                continue
            
            c = data.GARAGEDDETAILS.loc[i].split(' ')[0].lower()
            
            if c in GARAGEDDETAILS_content:
                MyData['GARAGEDDETAILS' + '_' + c].loc[i] = 1
    
    
  
    def INSEBCTEXT(self, data, MyData, feature_names):
        
        INSEBCTEXT_content = list(np.load('INSEBCTEXT_content.npy'))
        
        for i in range(4763,5558):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.INSEBCTEXT.isnull()[i] == True:
                continue
            
            c = re.sub('[^a-zA-Z]','',data.INSEBCTEXT.loc[i]).lower()
            
            if c in INSEBCTEXT_content:
                MyData['INSEBCTEXT' + '_' + c].loc[i] = 1
    
    
    def MARITALSTATUS(self, data, MyData, feature_names):
        
        MARITALSTATUS_content = ['n', 'u', 'y']
        
        for i in range(5558,5561):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.MARITALSTATUS.isnull()[i] == True:
                continue
            
            c = data.MARITALSTATUS.loc[i].split(' ')[0].lower()
            
            if c in MARITALSTATUS_content:
                MyData['MARITALSTATUS' + '_' + c].loc[i] = 1
    
    
    
    def OCCUPATION(self, data, MyData, feature_names):
        
        OCCUPATION_content = list(np.load('OCCUPATION_content.npy'))
        
        for i in range(5561,6821):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.OCCUPATION.isnull()[i] == True:
                continue
            
            c = re.sub('[^a-zA-Z]','',data.OCCUPATION.loc[i]).lower()
            
            if c in OCCUPATION_content:
                MyData['OCCUPATION' + '_' + c].loc[i] = 1
    
    
    
    
    def REGITEREDOWNER(self, data,  MyData, feature_names):
        
        REGITEREDOWNER_content = ['commonlawpartner', 'companyotherthanproposer', 'employee', 'employer', 'other', 'parent', 'proposerpolicyholder', 'sonordaughter', 'spouse', 'vehicleleasingcompan']
        
        for i in range(6821,6831):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.REGITEREDOWNER.isnull()[i] == True:
                continue
            
            c = re.sub('[^a-zA-Z]','',data.REGITEREDOWNER.loc[i]).lower()
            
            if c in REGITEREDOWNER_content:
                MyData['REGITEREDOWNER' + '_' + c].loc[i] = 1
    
     
    
    def RISKPOSTCODE1(self, data, MyData, feature_names):
        
        RISKPOSTCODE1_content = list(np.load('RISKPOSTCODE1_content.npy'))
        
        for i in range(6831,9306):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.RISKPOSTCODE.isnull()[i] == True:
                continue
            
            c = data.RISKPOSTCODE.loc[i].strip().split(' ')[0].lower()
            
            if c in RISKPOSTCODE1_content:
                MyData['RISKPOSTCODE1' + '_' + c].loc[i] = 1
   
    
    def RISKPOSTCODE2(self, data, MyData, feature_names):
        
        RISKPOSTCODE2_content = list(np.load('RISKPOSTCODE2_content.npy'))
        
        for i in range(9306,13170):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.RISKPOSTCODE.isnull()[i] == True:
                continue
            
            c = data.RISKPOSTCODE.loc[i].strip().split(' ')[-1].lower()
            
            if c in RISKPOSTCODE2_content:
                MyData['RISKPOSTCODE2' + '_' + c].loc[i] = 1
                
    
    
    def VEHICLEMAKE(self, data, MyData, feature_names):
        
        VEHICLEMAKE_content = list(np.load('VEHICLEMAKE_content.npy'))
        
        for i in range(13170,13205):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.VEHICLEMAKE.isnull()[i] == True:
                continue
            
            c = re.sub('[^a-zA-Z]','',data.VEHICLEMAKE.loc[i]).lower()
            
            if c in VEHICLEMAKE_content:
                MyData['VEHICLEMAKE' + '_' + c].loc[i] = 1
    
    
    def VEHICLEMODEL1(self, data, MyData, feature_names):
        
        VEHICLEMODEL1_content = list(np.load('VEHICLEMODEL1_content.npy'))
        
        for i in range(13205,13342):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.VEHICLEMODEL.isnull()[i] == True:
                continue
            
            c = data.VEHICLEMODEL.loc[i].strip().split(' ')[0].lower()
            
            if c in VEHICLEMODEL1_content:
                MyData['VEHICLEMODEL1' + '_' + c].loc[i] = 1
    
    
    
    def VEHICLEMODEL2(self, data, MyData, feature_names):
        
        VEHICLEMODEL2_content = list(np.load('VEHICLEMODEL2_content.npy'))
        
        for i in range(13342,13807):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.VEHICLEMODEL.isnull()[i] == True:
                continue
            
            s = data.VEHICLEMODEL.loc[i].strip().split(' ')
            if len(s) < 2:
                continue
            
            c = re.sub('[^a-zA-Z0-9]','',s[1]).lower()
            if c in VEHICLEMODEL2_content:
                MyData['VEHICLEMODEL2' + '_' + c].loc[i] = 1
    
    
    
    def VEHICLEMODEL3(self, data, MyData, feature_names):
        
        VEHICLEMODEL3_content = list(np.load('VEHICLEMODEL3_content.npy'))
        
        for i in range(13807,14190):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.VEHICLEMODEL.isnull()[i] == True:
                continue
            
            s = data.VEHICLEMODEL.loc[i].strip().split(' ')
            if len(s) < 3:
                continue
            
            c = re.sub('[^a-zA-Z0-9]','',s[2]).lower()
            if c in VEHICLEMODEL3_content:
                MyData['VEHICLEMODEL3' + '_' + c].loc[i] = 1
    
    
    def VEHICLEMODEL4(self, data, MyData, feature_names):
        
        VEHICLEMODEL4_content = list(np.load('VEHICLEMODEL4_content.npy'))
        
        for i in range(14190,14524):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.VEHICLEMODEL.isnull()[i] == True:
                continue
            
            s = data.VEHICLEMODEL.loc[i].strip().split(' ')
            if len(s) < 4:
                continue
            
            c = re.sub('[^a-zA-Z0-9]','',s[3]).lower()
            if c in VEHICLEMODEL4_content:
                MyData['VEHICLEMODEL4' + '_' + c].loc[i] = 1
    
    
    
    def VEHICLETYPE(self, data, MyData, feature_names):
        
        VEHICLETYPE_content = list(np.load('VEHICLETYPE_content.npy'))
        
        for i in range(14524,14541):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.VEHICLETYPE.isnull()[i] == True:
                continue
            
            c = re.sub('[^a-zA-Z0-9]','',data.VEHICLETYPE.loc[i]).lower()
            
            if c in VEHICLETYPE_content:
                MyData['VEHICLETYPE' + '_' + c].loc[i] = 1
    
    
    
    def VEHICLEUSE(self, data, MyData, feature_names):
        
        VEHICLEUSE_content = list(np.load('VEHICLEUSE_content.npy'))
        
        for i in range(14541,14552):
            MyData[feature_names[i]] = 0
        
        for i in range(len(data)):
            if data.VEHICLEUSE.isnull()[i] == True:
                MyData['Unnamed: 0.1'] = 1
            
            else:
                c = re.sub('[^a-zA-Z0-9]','',data.VEHICLEUSE.loc[i]).lower()

                if c in VEHICLEUSE_content:
                    MyData['VEHICLEUSE' + '_' + c].loc[i] = 1
    
    
    def Time_difference(self, MyData, feature_names):

        MyData['Time_difference'] = 365
    
   
    
    def INSUREDAGE_DAY(self, data, MyData, feature_names):

        MyData['INSUREDAGE_DAY'] = 0
        for i in range(len(data)):
            
            MyData['INSUREDAGE_DAY'].loc[i] = 365 * data['INSUREDAGE'].loc[i]
    
    
    def VEHICLEYOM(self, data, MyData, feature_names):

        MyData['VEHICLEYOM'] = 0
        for i in range(len(data)):
            
            MyData['VEHICLEYOM'].loc[i] = data['VEHICLEYOM'].loc[i]
    
    
    def VEHICLECC(self, data, MyData, feature_names):

        MyData['VEHICLECC'] = 0
        for i in range(len(data)):
            
            MyData['VEHICLECC'].loc[i] = data['VEHICLECC'].loc[i]
    
    
    
    def VEHICLEGROUP(self, data, MyData, feature_names):

        MyData['VEHICLEGROUP'] = 0
        for i in range(len(data)):
            
            MyData['VEHICLEGROUP'].loc[i] = data['VEHICLEGROUP'].loc[i]
    
    
    def VEHICLEVALUE(self, data, MyData, feature_names):

        MyData['VEHICLEVALUE'] = 0
        for i in range(len(data)):

            MyData['VEHICLEVALUE'].loc[i] = data['VEHICLEVALUE'].loc[i]

    
    def VEHICLENUMBEROFSEATS(self, data, MyData, feature_names):

        MyData['VEHICLENUMBEROFSEATS'] = 0
        for i in range(len(data)):

            MyData['VEHICLENUMBEROFSEATS'].loc[i] = data['VEHICLENUMBEROFSEATS'].loc[i]

    
    
    def NCBYEARS(self, data, MyData, feature_names):

        MyData['NCBYEARS'] = 0
        for i in range(len(data)):

            MyData['NCBYEARS'].loc[i] = data['NCBYEARS'].loc[i]

    
    def PROTECTEDNCB(self, data, MyData, feature_names):

        MyData['PROTECTEDNCB'] = 0
        for i in range(len(data)):

            if data['PROTECTEDNCB'].loc[i] == "Y":
                MyData['PROTECTEDNCB'].loc[i] = 1
            else:
                MyData['PROTECTEDNCB'].loc[i] = 0

                
    def VOLUNTARYXS(self, data, MyData, feature_names):

        MyData['VOLUNTARYXS'] = 0
        for i in range(len(data)):

            MyData['VOLUNTARYXS'].loc[i] = data['VOLUNTARYXS'].loc[i]

    
    
    def NUMBERADDITIONAL(self, data, MyData, feature_names):

        MyData['NUMBERADDITIONAL'] = 0
        for i in range(len(data)):
            if data.NOOFDRIVERS.isnull()[i] == True:
                continue
            MyData['NUMBERADDITIONAL'].loc[i] = data['NOOFDRIVERS'].loc[i] - 1


    
    def ADDITIONALDRIVER1AGE(self, data, MyData, feature_names):
        MyData['ADDITIONALDRIVER1AGE'] = 15424
        for i in range(len(data)):
            if data.ADDITIONALDRIVER1DOB.isnull()[i] == True:
                continue

            MyData['ADDITIONALDRIVER1AGE'].loc[i] = (float(data['POLICYSTARTDATE'].loc[i][-4:]) - float(data['ADDITIONALDRIVER1DOB'].loc[i][-4:])) * 365



    def ADDITIONALDRIVER2AGE(self, data, MyData, feature_names):
        MyData['ADDITIONALDRIVER2AGE'] = 15997
        for i in range(len(data)):
            if data.ADDITIONALDRIVER2DOB.isnull()[i] == True:
                continue

            MyData['ADDITIONALDRIVER2AGE'].loc[i] = (float(data['POLICYSTARTDATE'].loc[i][-4:]) - float(data['ADDITIONALDRIVER2DOB'].loc[i][-4:])) * 365


    def CONVTIME1(self, data, MyData, feature_names):
        MyData['CONVTIME1'] = 0
        for i in range(len(data)):
            if data.CONV1DATE.isnull()[i] == True:
                continue

            MyData['CONVTIME1'].loc[i] = (float(data['POLICYSTARTDATE'].loc[i][-4:]) - float(data['CONV1DATE'].loc[i][-4:])) * 365

    
    def CONV2TIME(self, data, MyData, feature_names):
        MyData['CONV2TIME'] = 0
        for i in range(len(data)):
            if data.CONV2DATE.isnull()[i] == True:
                continue

            MyData['CONV2TIME'].loc[i] = (float(data['POLICYSTARTDATE'].loc[i][-4:]) - float(data['CONV2DATE'].loc[i][-4:])) * 365

    
    
    def ACCIDENTIME1(self, data, MyData, feature_names):
        MyData['ACCIDENTIME1'] = 0
        for i in range(len(data)):
            if data.ACCIDENTDATE1.isnull()[i] == True:
                continue

            MyData['ACCIDENTIME1'].loc[i] = (float(data['POLICYSTARTDATE'].loc[i][-4:]) - float(data['ACCIDENTDATE1'].loc[i][-4:])) * 365

    
    def ACCIDENTAMOUNT1(self, data, MyData, feature_names):

        MyData['ACCIDENTAMOUNT1'] = 0
        for i in range(len(data)):
            if data.ACCIDENTAMOUNT1.isnull()[i] == True:
                continue
            MyData['ACCIDENTAMOUNT1'].loc[i] = data['ACCIDENTAMOUNT1'].loc[i] 
    
    
    def ACCIDENTIME2(self, data, MyData, feature_names):
        MyData['ACCIDENTIME2'] = 0
        for i in range(len(data)):
            if data.ACCIDENTDATE2.isnull()[i] == True:
                continue

            MyData['ACCIDENTIME2'].loc[i] = (float(data['POLICYSTARTDATE'].loc[i][-4:]) - float(data['ACCIDENTDATE2'].loc[i][-4:])) * 365

    
    def ACCIDENTAMOUNT2(self, data, MyData, feature_names):

        MyData['ACCIDENTAMOUNT2'] = 0
        for i in range(len(data)):
            if data.ACCIDENTAMOUNT2.isnull()[i] == True:
                continue
            MyData['ACCIDENTAMOUNT2'].loc[i] = data['ACCIDENTAMOUNT2'].loc[i] 
    
    
    def INSUREDLICSINMONTHS(self, data, MyData, feature_names):

        MyData['INSUREDLICSINMONTHS'] = 0
        for i in range(len(data)):
            if data.INSUREDLICSINMONTHS.isnull()[i] == True:
                continue
            MyData['INSUREDLICSINMONTHS'].loc[i] = data['INSUREDLICSINMONTHS'].loc[i] 
    
    
    
    def ADDDVRLICSINMONTHS1(self, data, MyData, feature_names):

        MyData['ADDDVRLICSINMONTHS1'] = 220
        for i in range(len(data)):
            if data.ADDDVRLICSINMONTHS1.isnull()[i] == True:
                continue
            MyData['ADDDVRLICSINMONTHS1'].loc[i] = data['ADDDVRLICSINMONTHS1'].loc[i] 
    
    
    def ADDDVRLICSINMONTHS2(self, data, MyData, feature_names):

        MyData['ADDDVRLICSINMONTHS2'] = 235.8
        for i in range(len(data)):
            if data.ADDDVRLICSINMONTHS2.isnull()[i] == True:
                continue
            MyData['ADDDVRLICSINMONTHS2'].loc[i] = data['ADDDVRLICSINMONTHS2'].loc[i] 
    
    
    def ADDDVREBC1(self, data, MyData, feature_names):

        MyData['ADDDVREBC1'] = 0
        for i in range(len(data)):
            if data.ADDDVREBC1.isnull()[i] == True:
                continue
            MyData['ADDDVREBC1'].loc[i] = data['ADDDVREBC1'].loc[i] 
    
    
    def ADDDVREBC2(self, data, MyData, feature_names):

        MyData['ADDDVREBC2'] = 0
        for i in range(len(data)):
            if data.ADDDVREBC2.isnull()[i] == True:
                continue
            MyData['ADDDVREBC2'].loc[i] = data['ADDDVREBC2'].loc[i] 
    
    
    
    def CURRENTMILEAGE(self, data, MyData, feature_names):

        MyData['CURRENTMILEAGE'] = 0
        for i in range(len(data)):
            if data.CURRENTMILEAGE.isnull()[i] == True:
                continue
            MyData['CURRENTMILEAGE'].loc[i] = data['CURRENTMILEAGE'].loc[i] 
    
    
    
    
    def ANNUALMILEAGE(self, data, MyData, feature_names):

        MyData['ANNUALMILEAGE'] = 0
        for i in range(len(data)):
            if data.ANNUALMILEAGE.isnull()[i] == True:
                continue
            MyData['ANNUALMILEAGE'].loc[i] = data['ANNUALMILEAGE'].loc[i] 
    
    
    
    def VEHICLECARRIESSIGNAGEYN(self, data, MyData, feature_names):

        MyData['VEHICLECARRIESSIGNAGEYN'] = 0
        for i in range(len(data)):

            if data['VEHICLECARRIESSIGNAGEYN'].loc[i] == "Y":
                MyData['VEHICLECARRIESSIGNAGEYN'].loc[i] = 1
            else:
                MyData['VEHICLECARRIESSIGNAGEYN'].loc[i] = 0
    
    
    def RACKINFITTEDYN(self, data, MyData, feature_names):

        MyData['RACKINFITTEDYN'] = 0
        for i in range(len(data)):

            if data['RACKINFITTEDYN'].loc[i] == "Y":
                MyData['RACKINFITTEDYN'].loc[i] = 1
            else:
                MyData['RACKINFITTEDYN'].loc[i] = 0
    
    
    def HAZARDOUSGOODSCARRIEDYN(self, data, MyData, feature_names):

        MyData['HAZARDOUSGOODSCARRIEDYN'] = 0
        for i in range(len(data)):

            if data['HAZARDOUSGOODSCARRIEDYN'].loc[i] == "Y":
                MyData['HAZARDOUSGOODSCARRIEDYN'].loc[i] = 1
            else:
                MyData['HAZARDOUSGOODSCARRIEDYN'].loc[i] = 0
    
    
    def YearsVehicleOwned(self, data, MyData, feature_names):

        MyData['YearsVehicleOwned'] = 0
    
    
    
    
    def HOMEOWNER(self, data, MyData, feature_names):

        MyData['HOMEOWNER'] = 0
        for i in range(len(data)):

            if data['HOMEOWNER'].loc[i] == "Y":
                MyData['HOMEOWNER'].loc[i] = 1
            else:
                MyData['HOMEOWNER'].loc[i] = 0
    
    
    
    
    def NOOFDRIVERS(self, data, MyData, feature_names):

        MyData['NOOFDRIVERS'] = 0
        for i in range(len(data)):
            if data.NOOFDRIVERS.isnull()[i] == True:
                continue
            MyData['NOOFDRIVERS'].loc[i] = data['NOOFDRIVERS'].loc[i] 
    
    
    
    def unknown(self, data, MyData, feature_names):

        MyData['COMPADXS'] = 0
        MyData['VOLADXS'] = 0
        MyData['COMPFTXS'] = 0
        MyData['VOLFTXS'] = 0
        MyData['VOLFMXS'] = 0
        MyData['COMPASXS'] = 0
        MyData['COMPWSXS'] = 0
        MyData['COMPADFT'] = 0
        MyData['VOLADFT'] = 0
        MyData['VOLASXS'] = 0
        
        
        for i in range(len(data)):
            
            MyData['COMPADXS'].loc[i] = data['COMPADXS'].loc[i]
            MyData['VOLADXS'].loc[i] = data['VOLADXS'].loc[i]
            MyData['COMPFTXS'].loc[i] = data['COMPFTXS'].loc[i]
            MyData['VOLFTXS'].loc[i] = data['VOLFTXS'].loc[i]
            MyData['VOLFMXS'].loc[i] = data['VOLFMXS'].loc[i]
            MyData['COMPASXS'].loc[i] = data['COMPASXS'].loc[i]
            MyData['COMPWSXS'].loc[i] = data['COMPWSXS'].loc[i]
            MyData['COMPADFT'].loc[i] = data['COMPADFT'].loc[i]
            MyData['VOLADFT'].loc[i] = data['VOLADFT'].loc[i]
            MyData['VOLASXS'].loc[i] = data['VOLASXS'].loc[i]
    
    
    
    def ADDITIONALDRIVER1RESidencyyears(self, data, MyData, feature_names):

        MyData['ADDITIONALDRIVER1RESidencyyears'] = 0
        for i in range(len(data)):
            if data.ADDITIONALDRIVER1RESidencyyears.isnull()[i] == True:
                continue
            MyData['ADDITIONALDRIVER1RESidencyyears'].loc[i] = data['ADDITIONALDRIVER1RESidencyyears'].loc[i] 
    
    
    
    def ADDITIONALDRIVER2RES(self, data, MyData, feature_names):

        MyData['ADDITIONALDRIVER2RES'] = 0
        for i in range(len(data)):
            if data.ADDITIONALDRIVER2RES.isnull()[i] == True:
                continue
            MyData['ADDITIONALDRIVER2RES'].loc[i] = data['ADDITIONALDRIVER2RES'].loc[i] 
    
    
    
    def UKRESIDENTYN(self, data, MyData, feature_names):

        MyData['UKRESIDENTYN'] = 0
        for i in range(len(data)):

            if data['UKRESIDENTYN'].loc[i] == "Y":
                MyData['UKRESIDENTYN'].loc[i] = 1
            else:
                MyData['UKRESIDENTYN'].loc[i] = 0
    
    
    def MONTHSINUK(self, data, MyData, feature_names):

        MyData['MONTHSINUK'] = 0
        for i in range(len(data)):
            if data.MONTHSINUK.isnull()[i] == True:
                continue
            MyData['MONTHSINUK'].loc[i] = data['MONTHSINUK'].loc[i] 
    
    
    
    
    def ADDDVRMONTHSINUK1(self, data, MyData, feature_names):

        MyData['ADDDVRMONTHSINUK1'] = 0
        for i in range(len(data)):
            if data.ADDDVRMONTHSINUK1.isnull()[i] == True:
                continue
            MyData['ADDDVRMONTHSINUK1'].loc[i] = data['ADDDVRMONTHSINUK1'].loc[i] 
    
    
    
    
    def ADDDVRMONTHSINUK2(self, data, MyData, feature_names):

        MyData['ADDDVRMONTHSINUK2'] = 0
        for i in range(len(data)):
            if data.ADDDVRMONTHSINUK2.isnull()[i] == True:
                continue
            MyData['ADDDVRMONTHSINUK2'].loc[i] = data['ADDDVRMONTHSINUK2'].loc[i] 
    
  
    def RADIUSLIMIT(self, data, MyData, feature_names):

        MyData['RADIUSLIMIT'] = 100
   


    def CONFINE1(self, data, MyData, feature_names):

        MyData['CONFINE1_1'] = 0
        MyData['CONFINE1_2'] = 0
        MyData['CONFINE1_3'] = 0
        MyData['CONFINE1_4'] = 0
        
        for i in range(len(data)):
            if data.CONV1FINE.isnull()[i] == True:
                continue
            lll = []
            for j,k in enumerate(data.CONV1FINE.loc[i]):
                if k == '/':
                    lll.append(j)
            
            try:
                MyData['CONFINE1_1'].loc[i] = int(data.CONV1FINE.loc[i][0:lll[0]])
                MyData['CONFINE1_2'].loc[i] = int(data.CONV1FINE.loc[i][lll[0] + 1:lll[1]])
                MyData['CONFINE1_3'].loc[i] = int(data.CONV1FINE.loc[i][lll[1] + 1:lll[2]])
                MyData['CONFINE1_4'].loc[i] = int(data.CONV1FINE.loc[i][lll[2] + 1:])
            except:
                pass


    
    def CONFINE2(self, data, MyData, feature_names):

        MyData['CONFINE2_1'] = 0
        MyData['CONFINE2_2'] = 0
        MyData['CONFINE2_3'] = 0
        MyData['CONFINE2_4'] = 0
        
        for i in range(len(data)):
            if data.CONV2FINE.isnull()[i] == True:
                continue
            lll = []
            for j,k in enumerate(data.CONV2FINE.loc[i]):
                if k == '/':
                    lll.append(j)
            
            try:
                MyData['CONFINE2_1'].loc[i] = int(data.CONV2FINE.loc[i][0:lll[0]])
                MyData['CONFINE2_2'].loc[i] = int(data.CONV2FINE.loc[i][lll[0] + 1:lll[1]])
                MyData['CONFINE2_3'].loc[i] = int(data.CONV2FINE.loc[i][lll[1] + 1:lll[2]])
                MyData['CONFINE2_4'].loc[i] = int(data.CONV2FINE.loc[i][lll[2] + 1:])
            
            except:
                pass

# %%
data = pd.read_csv("test_examples.csv")
feature_names = np.load('feature_names.npy')
l = list(feature_names)

# %%
start = time.time()

MyData = pd.DataFrame(data['Policynumber'], columns = ['Policynumber'])
Preprocessing().ADDDVREBCTEXT1(data, MyData, l)
Preprocessing().ADDDVREBCTEXT2(data, MyData, l)
Preprocessing().ADDDVRLICTYPE1(data, MyData, l)
Preprocessing().ADDDVRLICTYPE2(data, MyData, l)
Preprocessing().ADDDVRMARITALSTATUS1(data, MyData, l)
Preprocessing().ADDDVRMARITALSTATUS2(data, MyData, l)
Preprocessing().ADDDVROCCUPATION1(data, MyData, l)
Preprocessing().ADDDVROCCUPATION2(data, MyData, l)
Preprocessing().ADDDVROCCUPATIONTEXT1(data, MyData, l)
Preprocessing().ADDDVROCCUPATIONTEXT2(data, MyData, l)
Preprocessing().ADDDVRSEX2(data, MyData, l)
Preprocessing().ADDITIONALDRIVER1(data, MyData, l)
Preprocessing().ADDITIONALDRIVER1REL(data, MyData, l)
Preprocessing().ADDITIONALDRIVER2(data, MyData, l)
Preprocessing().ADDITIONALDRIVER2REL(data, MyData, l)
Preprocessing().CONV1OFFENCECODE(data, MyData, l)
Preprocessing().CONV2OFFENCECODE(data, MyData, l)
Preprocessing().COVER(data, MyData, l)
Preprocessing().DRIVERNAMEACCT1(data, MyData, l)
Preprocessing().DRIVERNAMEACCT2(data, MyData, l)
Preprocessing().DRIVERNAMECONV1(data, MyData, l)
Preprocessing().DRIVERNAMECONV2(data, MyData, l)
Preprocessing().EMPLOYMENTSTATUS(data, MyData, l)
Preprocessing().FAULTCODE1(data, MyData, l)
Preprocessing().FAULTCODE2(data, MyData, l)
Preprocessing().FUEL(data, MyData, l)
Preprocessing().GARAGEDDETAILS(data, MyData, l)
Preprocessing().INSEBCTEXT(data, MyData, l)
Preprocessing().MARITALSTATUS(data, MyData, l)
Preprocessing().OCCUPATION(data, MyData, l)
Preprocessing().REGITEREDOWNER(data, MyData, l)
Preprocessing().RISKPOSTCODE1(data, MyData, l)
Preprocessing().RISKPOSTCODE2(data, MyData, l)
Preprocessing().VEHICLEMAKE(data, MyData, l)
Preprocessing().VEHICLEMODEL1(data, MyData, l)
Preprocessing().VEHICLEMODEL2(data, MyData, l)
Preprocessing().VEHICLEMODEL3(data, MyData, l)
Preprocessing().VEHICLEMODEL4(data, MyData, l)
Preprocessing().VEHICLETYPE(data, MyData, l)
Preprocessing().VEHICLEUSE(data, MyData, l)
Preprocessing().Time_difference( MyData, l)
Preprocessing().INSUREDAGE_DAY(data, MyData, l)
Preprocessing().VEHICLEYOM(data, MyData, l)
Preprocessing().VEHICLECC(data, MyData, l)
Preprocessing().VEHICLEGROUP(data, MyData, l)
Preprocessing().VEHICLEVALUE(data, MyData, l)
Preprocessing().VEHICLENUMBEROFSEATS(data, MyData, l)
Preprocessing().NCBYEARS(data, MyData, l)
Preprocessing().PROTECTEDNCB(data, MyData, l)
Preprocessing().VOLUNTARYXS(data, MyData, l)
Preprocessing().NUMBERADDITIONAL(data, MyData, l)
Preprocessing().ADDITIONALDRIVER1AGE(data, MyData, l)
Preprocessing().ADDITIONALDRIVER2AGE(data, MyData, l)
Preprocessing().CONVTIME1(data, MyData, l)
Preprocessing().CONV2TIME(data, MyData, l)
Preprocessing().ACCIDENTIME1(data, MyData, l)
Preprocessing().ACCIDENTAMOUNT1(data, MyData, l)
Preprocessing().ACCIDENTIME2(data, MyData, l)
Preprocessing().ACCIDENTAMOUNT2(data, MyData, l)
Preprocessing().INSUREDLICSINMONTHS(data, MyData, l)
Preprocessing().ADDDVRLICSINMONTHS1(data, MyData, l)
Preprocessing().ADDDVRLICSINMONTHS2(data, MyData, l)
Preprocessing().ADDDVREBC1(data, MyData, l)
Preprocessing().ADDDVREBC2(data, MyData, l)
Preprocessing().CURRENTMILEAGE(data, MyData, l)
Preprocessing().ANNUALMILEAGE(data, MyData, l)
Preprocessing().VEHICLECARRIESSIGNAGEYN(data, MyData, l)
Preprocessing().RACKINFITTEDYN(data, MyData, l)
Preprocessing().HAZARDOUSGOODSCARRIEDYN(data, MyData, l)
Preprocessing().YearsVehicleOwned(data, MyData, l)
Preprocessing().HOMEOWNER(data, MyData, l)
Preprocessing().NOOFDRIVERS(data, MyData, l)
Preprocessing().unknown(data, MyData, l)
Preprocessing().ADDITIONALDRIVER1RESidencyyears(data, MyData, l)
Preprocessing().ADDITIONALDRIVER2RES(data, MyData, l)
Preprocessing().UKRESIDENTYN(data, MyData, l)
Preprocessing().MONTHSINUK(data, MyData, l)
Preprocessing().ADDDVRMONTHSINUK1(data, MyData, l)
Preprocessing().ADDDVRMONTHSINUK2(data, MyData, l)
Preprocessing().RADIUSLIMIT(data, MyData, l)
Preprocessing().CONFINE1(data, MyData, l)
Preprocessing().CONFINE2(data, MyData, l)


print("Took {} seconds.".format(time.time() - start))
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Took 15.652469873428345 seconds.

# %%
MyData
# Out:
#   Policynumber  ADDDVREBCTEXT1_accountancy  ADDDVREBCTEXT1_acousticengineer  \
# 0  ANCV0007015                           0                                0
#
#    ADDDVREBCTEXT1_addressingcircularisingservices  ADDDVREBCTEXT1_advertising  \
# 0                                               0                           0
#
#    ADDDVREBCTEXT1_aerialerector  ADDDVREBCTEXT1_aerialmanufacturer  \
# 0                             0                                  0
#
#    ADDDVREBCTEXT1_aerialphotography  ADDDVREBCTEXT1_aerialsupplier  \
# 0                                 0                              0
#
#    ADDDVREBCTEXT1_aerospaceindustry     ...      ADDDVRMONTHSINUK2  \
# 0                                 0     ...                      0
#
#    RADIUSLIMIT  CONFINE1_1  CONFINE1_2  CONFINE1_3  CONFINE1_4  CONFINE2_1  \
# 0          100          60           3           0           0          60
#
#    CONFINE2_2  CONFINE2_3  CONFINE2_4
# 0           3           0           0
#
# ...

# %%
from sklearn.externals import joblib
clf = joblib.load("GBDT_model.m")
results = clf.predict_proba(np.array(MyData.drop(['Policynumber'],axis=1)))
print(results)
# Out:
# [[0.99579151 0.00420849]]
